# %% [markdown]
# ABC Technologies – IT Consulting

# %% [markdown]
# ![Screenshot (598).png](attachment:26822ad1-06e9-4e84-836c-88bb6cba9887.png)

# %%
import numpy as np
emp_dept=['HR','IT','Finance','Sales']
no_of_emplyoees=[3, 15, 5, 7]
range_Eid=['1-3','4-18','19-23','24-30']
emp_data=np.array((emp_dept,no_of_emplyoees,range_Eid))
print(emp_data)
# Out:
# [['HR' 'IT' 'Finance' 'Sales']
#  ['3' '15' '5' '7']
#  ['1-3' '4-18' '19-23' '24-30']]

# %% [markdown]
# ![Screenshot (599).png](attachment:db2524d7-8db0-4a9f-91d7-2d159037106a.png)

# %%
import numpy as np
emp_dept=['HR','IT','Finance','Sales']
no_of_emplyoees=[3, 15, 5, 7]
#range_Eid=['1-3','4-18','19-23','24-30']
emp_data=np.array((emp_dept,no_of_emplyoees,range_Eid))
#task 2
HR_salaries=np.array([50,60,57])
IT_salaries=np.array([67,67,67,67,67,67,67,67,67,67,67,67,67,67,67])
Finance_salaries=np.array([60,65,50,70,87])
Sales_salaries=np.array([50,60,65,90,56,65,71])
print(f' The salaries of HR dept is :{HR_salaries}')
print(f' The salaries of IT dept is :{IT_salaries}')
print(f' The salaries of Finance dept is :{Finance_salaries}')
print(f' The salaries of Sales dept is :{Sales_salaries}')
# Out:
#  The salaries of HR dept is :[50 60 57]
#  The salaries of IT dept is :[67 67 67 67 67 67 67 67 67 67 67 67 67 67 67]
#  The salaries of Finance dept is :[60 65 50 70 87]
#  The salaries of Sales dept is :[50 60 65 90 56 65 71]

# %% [markdown]
# ![Screenshot (600).png](attachment:06189174-03b4-499e-a7e5-12955eb2eed7.png)

# %%
#task 2
HR_salaries=np.array([50,60,57])
IT_salaries=np.array([67,67,67,67,67,67,67,67,67,67,67,67,67,67,67])
Finance_salaries=np.array([60,65,50,70,87])
Sales_salaries=np.array([50,60,65,90,56,65,71])
print(f' The salaries of HR dept is :{HR_salaries}')
print(f' The salaries of IT dept is :{IT_salaries}')
print(f' The salaries of Finance dept is :{Finance_salaries}')
print(f' The salaries of Sales dept is :{Sales_salaries}')
#task 3
print(f'HR dept average salary expenses :{np.mean(HR_salaries)}')#  55.666666666666664
print(f'IT dept average salary expenses :{np.mean(IT_salaries)}')#   67.0
print(f'Finance dept average salary expenses :{np.mean(Finance_salaries)}')# 66.4
print(f'Sales dept average salary expenses :{np.mean(Sales_salaries)}') # 65.28571428571429
# IT DEPARTMENT HAS HIGHEST AVERAGE SALARY EXPENSE ON THE EMPLOYEES
# Out:
#  The salaries of HR dept is :[50 60 57]
#  The salaries of IT dept is :[67 67 67 67 67 67 67 67 67 67 67 67 67 67 67]
#  The salaries of Finance dept is :[60 65 50 70 87]
#  The salaries of Sales dept is :[50 60 65 90 56 65 71]
# HR dept average salary expenses :55.666666666666664
# IT dept average salary expenses :67.0
# Finance dept average salary expenses :66.4
# Sales dept average salary expenses :65.28571428571429
# The department with the highest average salary is :67.0

# %% [markdown]
# ![Screenshot (601).png](attachment:6ff01ce2-ea88-4933-a810-0b4a6e9cdd8e.png)

# %%
HR_salaries=np.array([50,60,57])
Finance_salaries=np.array([60,65,50,70,87])
print(f'The highest salarie in HR dept is {np.max(HR_salaries)}')
print(f'The highest salarie in Finance dept is {np.max(Finance_salaries)}')
# Out:
# The highest salarie in HR dept is 60
# The highest salarie in Finance dept is 87

# %% [markdown]
# ![Screenshot (602).png](attachment:20c9f799-760d-4739-88ba-60608f1abedb.png)

# %%
IT_salaries=np.array([67,67,67,67,67,67,67,67,67,67,67,67,67,67,67])
# since all have same salary and fresh joiny as per the above so we increase their sal by 5 % of 67 each
IT_salaries=np.array([67,67,67,67,67,67,67,67,67,67,67,67,67,67,67])
IT_salaries_updated_salary=IT_salaries*1.05
print(f'the orginal salary is {IT_salaries}')
print(f'the updated salary after bonus is {IT_salaries_updated_salary}')
# Out:
# the orginal salary is [67 67 67 67 67 67 67 67 67 67 67 67 67 67 67]
# the updated salary after bonus is [70.35 70.35 70.35 70.35 70.35 70.35 70.35 70.35 70.35 70.35 70.35 70.35
#  70.35 70.35 70.35]

# %% [markdown]
# University Admission Decision

# %% [markdown]
# ![Screenshot (603).png](attachment:0e55159b-928f-4311-af72-6e2a2c515e13.png)

# %%
from numpy import genfromtxt

# %%
adm_data=genfromtxt('Downloads/DS1_C4_S1_AdmissionPredict_Data_Practice__1_.csv',delimiter=',',skip_header=1)
print(adm_data)
# Out:
# [[  1.   337.   118.   ...   9.65   1.     0.92]
#  [  2.   324.   107.   ...   8.87   1.     0.76]
#  [  3.   316.   104.   ...   8.     1.     0.72]
#  ...
#  [398.   330.   116.   ...   9.45   1.     0.91]
#  [399.   312.   103.   ...   8.78   0.     0.67]
#  [400.   333.   117.   ...   9.66   1.     0.95]]

# %% [markdown]
# ![Screenshot (604).png](attachment:8886c8c4-2706-4c54-8817-b351a6650b67.png)

# %%
print(adm_data[:,1])
# Out:
# [337. 324. 316. 322. 314. 330. 321. 308. 302. 323. 325. 327. 328. 307.
#  311. 314. 317. 319. 318. 303. 312. 325. 328. 334. 336. 340. 322. 298.
#  295. 310. 300. 327. 338. 340. 331. 320. 299. 300. 304. 307. 308. 316.
#  313. 332. 326. 322. 329. 339. 321. 327. 313. 312. 334. 324. 322. 320.
#  316. 298. 300. 311. 309. 307. 304. 315. 325. 325. 327. 316. 318. 328.
#  332. 336. 321. 314. 314. 329. 327. 301. 296. 294. 312. 340. 320. 322.
#  340. 319. 315. 317. 314. 316. 318. 299. 298. 301. 303. 304. 306. 331.
#  332. 323. 322. 312. 314. 317. 326. 316. 329. 338. 331. 304. 305. 321.
#  301. 320. 311. 310. 299. 290. 296. 327. 335. 334. 310. 308. 301. 300.
#  323. 319. 326. 333. 339. 303. 309. 323. 333. 314. 312. 316. 326. 318.
#  329. 332. 331. 340. 325. 320. 315. 326. 339. 311. 334. 332. 321. 324.
#  326. 312. 315. 309. 306. 297. 315. 298. 318. 317. 329. 322. 302. 313.
#  293. 311. 312. 334. 322. 323. 321. 320. 329. 319. 309. 307. 300. 305.
# ...

# %% [markdown]
# ![Screenshot (605).png](attachment:e34b2d5f-7af2-4279-aa76-170cd49b0ef4.png)

# %%
p=np.where(adm_data[:,1]>320)
np.shape(p) # 1 column and 163 rows
print(f'{np.shape(p)[1]} students had a GRE score greater than 320')
#163 students had a GRE score greater than 320
# Out:
# 163 students had a GRE score greater than 320

# %% [markdown]
# ![Screenshot (606).png](attachment:4cb689cd-28a2-4b02-82ad-d431e6e74182.png)

# %%
i=np.where(adm_data[:,2]>110)# toefl score greater than 110
adm_data[i,-1]# chance of admit column
print(adm_data[i,-1]*100) # mul by 100
#calculating mean
print(f'so avg of around {np.mean(adm_data[i,-1]*100) } chance of admision for  students who have a TOEFL score greater than 110') #  so avg of around 86.391 % chance of admision for  students who have a TOEFL score greater than 110
# Out:
# [[92. 90. 84. 78. 70. 94. 95. 97. 94. 91. 90. 94. 87. 91. 86. 89. 78. 78.
#   72. 52. 55. 61. 78. 94. 96. 93. 72. 74. 96. 92. 94. 86. 90. 79. 74. 87.
#   91. 93. 94. 94. 85. 78. 84. 92. 96. 79. 89. 80. 90. 92. 97. 80. 81. 83.
#   96. 93. 94. 86. 81. 89. 89. 87. 85. 90. 89. 93. 93. 88. 90. 86. 94. 97.
#   97. 95. 96. 94. 93. 91. 76. 71. 82. 91. 88. 85. 86. 70. 76. 77. 93. 85.
#   90. 70. 83. 89. 80. 94. 93. 92. 89. 86. 90. 71. 80. 79. 80. 81. 80. 80.
#   83. 94. 93. 91. 86. 95. 96. 96. 84. 89. 91. 95.]]
# so avg of around 86.39166666666667 chance of admision for  students who have a TOEFL score greater than 110

# %% [markdown]
# ![Screenshot (607).png](attachment:3293b12b-5849-469d-b235-7cb2a3a622bf.png)

# %%
i=np.where((adm_data[:,1]>315) & (adm_data[:,2]>115) & (adm_data[:,7]==1))
#adm_data[i]
print(f' The total  number of students eligible for this scholarship is: {np.shape(i)[1]}')
print(f'The serial number of these students are as follows :{adm_data[i].T[0]}')
# Out:
#  The total  number of students eligible for this scholarship is: 41
# The serial number of these students are as follows :[  1.  23.  24.  25.  26.  33.  53.  71.  82.  98.  99. 108. 109. 121.
#  122. 130. 139. 142. 144. 149. 152. 172. 177. 188. 194. 203. 204. 213.
#  214. 215. 216. 260. 286. 287. 326. 338. 362. 373. 386. 398. 400.]
