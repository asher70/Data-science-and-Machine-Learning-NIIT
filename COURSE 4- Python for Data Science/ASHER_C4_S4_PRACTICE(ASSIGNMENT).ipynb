# %% [markdown]
# ![Screenshot (638).png](attachment:75261ca1-c173-4418-acb3-abf97090dbca.png)

# %%
# loading the data
import pandas as pd

# %%
df=pd.read_csv("DS1_C4_S4_Test_Scores_Data_Practice.csv")

# %%
df1=df# copying df value into variable to df1 variable

# %%
df1.isnull().sum() # gender and test1,test2 has missing values
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 4
# test2                 4
# dtype: int64

# %%
# gender
df1['gender'].value_counts() # male has highest count with 1071  so replacing missing value in that column by 'Male' as per question
# Out:
# gender
# Male      1071
# Female    1052
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].fillna('Male')

# %%
df1['gender'].value_counts() # checking replace 10 null values of the column with mode 'Male'
# Out:
# gender
# Male      1081
# Female    1052
# Name: count, dtype: int64

# %%
#test1
df1['test1'].mean()
# Out:
# 54.96195396899953

# %%
df1['test1']=df1['test1'].fillna(df1['test1'].mean())

# %%
df1.isnull().sum() # null value got replaced with mean
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                4
# dtype: int64

# %%
# test2
df1['test2'].median()
# Out:
# 68.0

# %%
df1['test2']=df1['test2'].fillna(df1['test2'].median())

# %%
df1.isnull().sum()# replac
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                0
# dtype: int64

# %%
df2=df1 # saving value in df2

# %% [markdown]
# ![Screenshot (639).png](attachment:7437a2e2-2115-44c1-b0d0-8fdee5e3e3a0.png)

# %%
df2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2128    False
# 2129    False
# 2130    False
# 2131    False
# 2132    False
# Length: 2133, dtype: bool

# %%
df2.iloc[:,5]# student_id
# Out:
# 0       2FHT3
# 1       3JIVH
# 2       3XOWE
# 3       556O0
# 4       74LOE
#         ...
# 2128    T8LSK
# 2129    VNP26
# 2130    YDR1Z
# 2131    YUEIH
# 2132    ZVCQ8
# Name: student_id, Length: 2133, dtype: object

# %%
# removing student id as it is pk

# %%
wsid=df2.loc[:,df2.columns!='student_id']
wsid
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# ...     ...            ...         ...       ...             ...     ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df_dup=wsid[wsid.duplicated(keep="first")]
df_dup # these are the duplicate row
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 38    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 50    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 106   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2067  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df_dup1=wsid[wsid.duplicated(keep=False)]
df_dup1
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 15    ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 33    ANKYI          Urban  Non-public       ZNS        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2076  ZOWMK          Urban      Public       QA2        Standard  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2114  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df_dup1=wsid[wsid.duplicated(keep="last")]
df_dup1
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 15    ANKYI          Urban  Non-public       6OL        Standard    Male
# 33    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 49    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 103   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2048  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2064  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2076  ZOWMK          Urban      Public       QA2        Standard  Female
# 2114  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
wsid.shape
# Out:
# (2133, 9)

# %%
wsid_drop=wsid.drop_duplicates()

# %%
wsid_drop.shape # after dekletion its size  got reduced from 2133 to 2034 rows
# Out:
# (2054, 9)

# %% [markdown]
# ![Screenshot (640).png](attachment:06d38311-c6af-4ef5-84d8-4226d6c916f0.png)

# %%
# syntax=dfname=dfname.replace(to_replace=[o1,o2,o3],value=[n1,n2,n3])

# %%
wsid_drop # tuitionfee_waiver
 # we have to replace below code with "No" and "Yes" respectively
# Does not qualify,Qualifies for reduced/free
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
wsid_rep=wsid_drop.replace(to_replace=["Does not qualify","Qualifies for reduced/free "],value=["No","Yes"])

# %%
wsid_rep # it is replaced
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#      tuitionfee_waiver  test1  test2
# 0                   No   62.0   72.0
# ...

# %% [markdown]
# ![Screenshot (641).png](attachment:e0973dd9-20fb-4c74-a34f-bcb6b117364c.png)

# %%
wsid_rep
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#      tuitionfee_waiver  test1  test2
# 0                   No   62.0   72.0
# ...

# %%
p=wsid_rep.groupby(['school'])[['test1']].mean()
p
# averagr of test1 scores of students at each school
# Out:
#             test1
# school
# ANKYI   61.263158
# CCAAW   64.707547
# CIMBB   65.069444
# CUQAM   53.866667
# DNQDD   54.275000
# FBUMG   62.891304
# GJJHK   53.236842
# GOKXL   50.888889
# GOOBU   38.430212
# IDGFP   75.279070
# KFZMY   41.900000
# KZKKE   37.461538
# LAYPA   62.035088
# OJOBU   56.202532
# QOQTS   52.647619
# UAGPU   62.452381
# UKPGS   78.537190
# UUUQX   67.011731
# VHDHF   52.666667
# VKWQH   52.151515
# VVTVA   36.186560
# ZMNYA   68.030303
# ZOWMK   41.603604

# %%
j=float(p.max()) # maxmium element
j
# Out:
# C:\Users\asher\AppData\Local\Temp\ipykernel_5472\2119424256.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   j=float(p.max()) # maxmium element
# 78.53719008264463

# %%
index = p[p["test1"] == j].index
index
# Out:
# Index(['UKPGS'], dtype='object', name='school')

# %%
print(f' The school name of school with the highest average test1 score is :{index[0]} ')
# Out:
#  The school name of school with the highest average test1 score is :UKPGS

# %% [markdown]
# ![Screenshot (642).png](attachment:1a3adb0d-3c78-4d39-903f-90f5135fbd38.png)

# %%
wsid_rep
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#      tuitionfee_waiver  test1  test2
# 0                   No   62.0   72.0
# ...

# %%
# syntax: dfnaem=pd.pivott_table(dfname1,index=['CTname'],values=[''],aggfunc='')

# %%
q=pd.pivot_table(wsid_rep,index=['school'],values=['test2'],aggfunc='max')
q
# Out:
#         test2
# school
# ANKYI    79.0
# CCAAW    91.0
# CIMBB    88.0
# CUQAM    76.0
# DNQDD    79.0
# FBUMG    88.0
# GJJHK    85.0
# GOKXL    77.0
# GOOBU    68.0
# IDGFP   100.0
# KFZMY    67.0
# KZKKE    62.0
# LAYPA    84.0
# OJOBU    84.0
# QOQTS    85.0
# UAGPU    83.0
# UKPGS    99.0
# UUUQX    91.0
# VHDHF    77.0
# VKWQH    82.0
# VVTVA    68.0
# ZMNYA    95.0
# ZOWMK    63.0

# %%
# top 5 schools
pt=q.sort_values('test2')# arranged the values
pt
# Out:
#         test2
# school
# KZKKE    62.0
# ZOWMK    63.0
# KFZMY    67.0
# VVTVA    68.0
# GOOBU    68.0
# CUQAM    76.0
# GOKXL    77.0
# VHDHF    77.0
# ANKYI    79.0
# DNQDD    79.0
# VKWQH    82.0
# UAGPU    83.0
# OJOBU    84.0
# LAYPA    84.0
# QOQTS    85.0
# GJJHK    85.0
# FBUMG    88.0
# CIMBB    88.0
# UUUQX    91.0
# CCAAW    91.0
# ZMNYA    95.0
# UKPGS    99.0
# IDGFP   100.0

# %%
pt.tail() # top 5 schools
# Out:
#         test2
# school
# UUUQX    91.0
# CCAAW    91.0
# ZMNYA    95.0
# UKPGS    99.0
# IDGFP   100.0

# %% [markdown]
# ![Screenshot (643).png](attachment:0afe7e24-e710-4681-b7b9-7de420a02801.png)

# %%
j=df2.loc[df2.index[wsid_drop.index],::].replace(to_replace=["Does not qualify","Qualifies for reduced/free "],value=["No","Yes"])
j # we retrieved schoolid aas we need in this problem
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 5     ANKYI          Urban  Non-public       6OL        Standard      7YZO8
# ...     ...            ...         ...       ...             ...        ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard      S4I5S
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender tuitionfee_waiver  test1  test2
# ...

# %%
kp=j[(j['school']=='FBUMG')&(j['classroom']=='5LQ')&(j['test2']>=80)]# main
kp
# Out:
#     school school_setting school_type classroom teaching_method student_id  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 468  FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 469  FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 470  FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 471  FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 472  FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# 474  FBUMG          Rural  Non-public       5LQ    Experimental      B9FSU
# 475  FBUMG          Rural  Non-public       5LQ    Experimental      EV13K
# 476  FBUMG          Rural  Non-public       5LQ    Experimental      I5H37
# 477  FBUMG          Rural  Non-public       5LQ    Experimental      JC5I9
# 478  FBUMG          Rural  Non-public       5LQ    Experimental      JPE2J
# ...

# %%
len(kp)
# Out:
# 15

# %%
s=pd.Series([500]*15)

# %%
new_df=pd.DataFrame(s,columns=['Scholarship Amounts'])

# %%
new_df
# Out:
#     Scholarship Amounts
# 0                   500
# 1                   500
# 2                   500
# 3                   500
# 4                   500
# 5                   500
# 6                   500
# 7                   500
# 8                   500
# 9                   500
# 10                  500
# 11                  500
# 12                  500
# 13                  500
# 14                  500

# %%
new = pd.concat([kp.reset_index(drop=True), new_df.reset_index(drop=True)], axis=1)

# %%
new
# Out:
#    school school_setting school_type classroom teaching_method student_id  \
# 0   FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 1   FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 2   FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 3   FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 4   FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 5   FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# 6   FBUMG          Rural  Non-public       5LQ    Experimental      B9FSU
# 7   FBUMG          Rural  Non-public       5LQ    Experimental      EV13K
# 8   FBUMG          Rural  Non-public       5LQ    Experimental      I5H37
# 9   FBUMG          Rural  Non-public       5LQ    Experimental      JC5I9
# 10  FBUMG          Rural  Non-public       5LQ    Experimental      JPE2J
# 11  FBUMG          Rural  Non-public       5LQ    Experimental      MFBYU
# ...

# %% [markdown]
# ![Screenshot (644).png](attachment:45f947ae-3c5c-45ed-9e9d-e98fafd00f67.png)

# %%
pd.crosstab(df['school_setting'],df['teaching_method'])
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %% [markdown]
# ![Screenshot (645).png](attachment:5e1df39f-9b98-467e-b125-86f48ec4f8b0.png)

# %%
df
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
df.groupby(['school_setting','gender'])[['gender']].count()
# Out:
#                        gender
# school_setting gender
# Rural          Female     228
#                Male       282
# Suburban       Female     368
#                Male       349
# Urban          Female     456
#                Male       450

# %% [markdown]
# ![Screenshot (646).png](attachment:8f67918c-48fb-4fdb-8046-5cf334db9da9.png)

# %%
df.groupby(['school_setting','gender'])[['test2']].mean()
# Out:
#                            test2
# school_setting gender
# Rural          Female  63.991228
#                Male    64.092199
# Suburban       Female  76.027174
#                Male    75.991404
# Urban          Female  61.179825
#                Male    62.424444
