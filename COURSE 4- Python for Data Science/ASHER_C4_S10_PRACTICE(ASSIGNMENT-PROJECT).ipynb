# %% [markdown]
# # ![Screenshot 2025-02-15 112423.png](attachment:61e2dd81-6c43-4b9d-af6a-96e96adb9d71.png)

# %%
import pandas as pd
c=pd.read_csv('cardata.csv')
#c.info()#ABS_(Anti-lock_Braking_System),Airbags, Hill_Assist 
#Model
c['ABS_(Anti-lock_Braking_System)'].isnull().sum()# 0 mv
c['Airbags'].isnull().sum()# 0 mv
c['Hill_Assist'].isnull().sum()# 0 mv
c['Model'].isnull().sum()# 0 mv
# Out:
# 0

# %%
#c['ABS_(Anti-lock_Braking_System)'].unique()#'Yes'
#c['Hill_Assist'].unique()#'Yes'
#c['Airbags'].unique()#!='17.19'

# %%
c.groupby('Model')[['ABS_(Anti-lock_Braking_System)','Hill_Assist','Airbags']].count()
# Out:
#               ABS_(Anti-lock_Braking_System)  Hill_Assist  Airbags
# Model
# 3-Series                                   3            3        3
# 458 Speciale                               1            1        1
# 458 Spider                                 1            1        1
# 488 Gtb                                    2            2        2
# 5-Series                                   3            3        3
# ...                                      ...          ...      ...
# Xylo                                       5            5        5
# Yaris                                     14           14       14
# Z4 Roadster                                2            2        2
# Zest                                      11           11       11
# Zs Ev                                      2            2        2
#
# [263 rows x 3 columns]

# %% [markdown]
# # we seperately filtered car which did pass this criteria

# %%
c[(c['ABS_(Anti-lock_Braking_System)']=='Yes') &( c['Hill_Assist']=='Yes')&(c['Airbags']!='17.19')]
# Out:
#       S. No.        Make          Model                    Variant  \
# 151      151  Volkswagen           Polo                     Gt Tsi
# 168      168        Ford      Freestyle         1.5L Tdci Titanium
# 169      169        Ford      Freestyle    1.5L Tdci Titanium Plus
# 171      171        Ford      Freestyle       1.2L Ti-Vct Titanium
# 172      172        Ford      Freestyle  1.2L Ti-Vct Titanium Plus
# ...      ...         ...            ...                        ...
# 1253    1253     Porsche  Cayenne Coupe                       Base
# 1254    1254     Porsche  Cayenne Coupe                      Turbo
# 1263    1263     Bentley    Flying Spur                         V8
# 1264    1264     Bentley    Flying Spur                        W12
# 1275    1275  Mitsubishi        Montero                     3.2 At
#
#       Displacement  Cylinders  Valves_Per_Cylinder  Fuel_Tank_Capacity_litre  \
# 151         1197.0        4.0                  4.0                      45.0
# ...

# %% [markdown]
# # ![Screenshot 2025-02-15 112429.png](attachment:e438634d-1d7c-40cc-be2a-b14f4af8ae2d.png)

# %%
#c.info()#Seating_Capacity,Central_Locking,Child_Safety_Locks,Model
c['Model'].isnull().sum()
c['Seating_Capacity'].isnull().sum()
c['Central_Locking'].isnull().sum()
c['Child_Safety_Locks'].isnull().sum()
# Out:
# 0

# %%
c.groupby('Model').agg({'Seating_Capacity':['mean'],'Central_Locking':['count'],'Child_Safety_Locks':['count']})
# Out:
#              Seating_Capacity Central_Locking Child_Safety_Locks
#                          mean           count              count
# Model
# 3-Series                  5.0               3                  3
# 458 Speciale              2.0               1                  1
# 458 Spider                2.0               1                  1
# 488 Gtb                   2.0               2                  2
# 5-Series                  5.0               3                  3
# ...                       ...             ...                ...
# Xylo                      7.2               5                  5
# Yaris                     5.0              14                 14
# Z4 Roadster               2.0               2                  2
# Zest                      5.0              11                 11
# Zs Ev                     5.0               2                  2
#
# [263 rows x 3 columns]

# %% [markdown]
# # ![Screenshot 2025-02-15 112434.png](attachment:436da729-eaac-4e89-a512-74d700640cef.png)

# %%
#c.info()#High_Speed_Alert_System,Door_Ajar_Warning,Fasten_Seat_Belt_Warning
c['High_Speed_Alert_System'].isnull().sum()
c['Door_Ajar_Warning'].isnull().sum()
c['Fasten_Seat_Belt_Warning'].isnull().sum()
# Out:
# 0

# %%
c['High_Speed_Alert_System'].unique()#'Yes'
c['Door_Ajar_Warning'].unique()#'Yes'
c['Fasten_Seat_Belt_Warning'].unique()#'Yes'
# Out:
# array(['17.19', 'Yes'], dtype=object)

# %% [markdown]
# # these car below have all the features of alert system analyssis

# %%
c[(c['High_Speed_Alert_System']=='Yes')&(c['Door_Ajar_Warning']=='Yes')&(c['Fasten_Seat_Belt_Warning']=='Yes')]
# Out:
#       S. No.     Make   Model                      Variant  Displacement  \
# 59        59     Tata   Tiago                 Revotron Xza        1199.0
# 60        60     Tata   Tiago            Revotron Xza Plus        1199.0
# 61        61     Tata   Tiago  Revotron Xza Plus Dual Tone        1199.0
# 77        77  Renault  Triber                          Rxe         999.0
# 136      136  Hyundai    Aura                Sx 1.2 Petrol        1197.0
# ...      ...      ...     ...                          ...           ...
# 1270    1270    Honda    City                  V Mt Diesel        1498.0
# 1271    1271    Honda    City                 Vx Mt Diesel        1498.0
# 1272    1272    Honda    City                 Zx Mt Diesel        1498.0
# 1273    1273    Honda    City                Zx Cvt Petrol        1497.0
# 1274    1274    Honda    City                 V Cvt Petrol        1497.0
#
#       Cylinders  Valves_Per_Cylinder  Fuel_Tank_Capacity_litre Fuel_Type  \
# ...

# %% [markdown]
# # ![Screenshot 2025-02-15 112439.png](attachment:03e2b135-ef77-4917-8527-a9ca7bdf9057.png)

# %%
#c.info()#Height_mm,Length_mm,Width_mm
c['Height_mm'].isnull().sum()
c['Length_mm'].isnull().sum()
c['Width_mm'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # anaylisis of dimensions of car for Model

# %%
c.groupby('Model').agg({'Height_mm':['mean','median','std'],'Length_mm':['mean','median','std'],'Width_mm':['mean','median','std']})
# Out:
#              Height_mm              Length_mm              Width_mm          \
#                   mean  median  std      mean  median  std     mean  median
# Model
# 3-Series        1429.0  1429.0  0.0    4633.0  4633.0  0.0   1811.0  1811.0
# 458 Speciale    1203.0  1203.0  NaN    4571.0  4571.0  NaN   1951.0  1951.0
# 458 Spider      1211.0  1211.0  NaN    4568.0  4568.0  NaN   1952.0  1952.0
# 488 Gtb         1213.0  1213.0  0.0    4568.0  4568.0  0.0   1952.0  1952.0
# 5-Series        1464.0  1464.0  0.0    4907.0  4907.0  0.0   1860.0  1860.0
# ...                ...     ...  ...       ...     ...  ...      ...     ...
# Xylo            1895.0  1895.0  0.0    4520.0  4520.0  0.0   1850.0  1850.0
# Yaris           1495.0  1495.0  0.0    4425.0  4425.0  0.0   1730.0  1730.0
# Z4 Roadster     1304.0  1304.0  0.0    4324.0  4324.0  0.0   1741.5  1741.5
# Zest            1570.0  1570.0  0.0    3995.0  3995.0  0.0   1706.0  1706.0
# ...

# %% [markdown]
# # anaylisis of dimensions of car for Make

# %%
c.groupby('Make').agg({'Height_mm':['mean','median','std'],'Length_mm':['mean','median','std'],'Width_mm':['mean','median','std']})
# Out:
#                     Height_mm                        Length_mm          \
#                          mean  median         std         mean  median
# Make
# Aston Martin      1294.333333  1273.0   58.020111  4623.000000  4465.0
# Audi              1493.941613  1485.0  309.853980  4715.096774  4718.0
# Bajaj             1652.000000  1652.0    0.000000  2752.000000  2752.0
# Bentley           1563.666667  1504.5  143.761840  5210.166667  5220.0
# Bmw               1541.486486  1481.0  132.685221  4816.891892  4894.0
# Bugatti           1212.000000  1212.0    0.000000  4544.000000  4544.0
# Datsun            1520.600000  1507.0   17.241147  3644.400000  3788.0
# Dc                1200.000000  1200.0         NaN  4565.000000  4565.0
# Ferrari           1275.250000  1244.5   77.755569  4668.125000  4570.0
# Fiat              1517.739130  1525.0   22.964830  4195.086957  3989.0
# Force             2061.666667  2055.0   10.327956  4108.666667  3992.0
# ...
