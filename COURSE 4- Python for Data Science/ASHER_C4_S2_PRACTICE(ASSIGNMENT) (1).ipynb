# %% [markdown]
# ![Screenshot (618).png](attachment:52feb44e-fc61-4a16-b154-5f2d677a0390.png)

# %%
import pandas  as pd
import numpy as np

# %%
p=np.arange(1001,1041)
p
# Out:
# array([1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011,
#        1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022,
#        1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033,
#        1034, 1035, 1036, 1037, 1038, 1039, 1040])

# %%
student_id=pd.Series(p)
student_id
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
# 5     1006
# 6     1007
# 7     1008
# 8     1009
# 9     1010
# 10    1011
# 11    1012
# 12    1013
# 13    1014
# 14    1015
# 15    1016
# 16    1017
# 17    1018
# 18    1019
# 19    1020
# 20    1021
# 21    1022
# 22    1023
# 23    1024
# 24    1025
# 25    1026
# 26    1027
# 27    1028
# 28    1029
# 29    1030
# 30    1031
# 31    1032
# 32    1033
# 33    1034
# 34    1035
# 35    1036
# 36    1037
# 37    1038
# 38    1039
# 39    1040
# dtype: int32

# %% [markdown]
# ![Screenshot (619).png](attachment:d21b4fdc-2116-4b9a-8586-84ac20a28513.png)

# %%
maths_marks=[35, 86, 63, 90, 50, 63, 15, 72, 15, 54, 72, 83, 58, 70, 92, 40, 59, 63, 53, 59, 55, 85, 18, 83, 67, 85, 46, 59, 77, 71, 77, 56, 79, 61, 82, 76, 60, 52, 88, 78]
physics_marks=[85, 94, 63, 59, 76, 64, 87, 55, 51, 71, 54, 94, 33, 72, 75, 67, 85, 15, 50, 50, 19, 55, 59, 65, 76, 13, 57, 70, 51, 94, 55, 50, 71, 91, 75, 51, 90, 70, 87, 56]

# %%
math=pd.Series(maths_marks,index=student_id)
print(math)
physics=pd.Series(physics_marks,index=student_id)
print(physics)
# Out:
# 1001    35
# 1002    86
# 1003    63
# 1004    90
# 1005    50
# 1006    63
# 1007    15
# 1008    72
# 1009    15
# 1010    54
# 1011    72
# 1012    83
# 1013    58
# 1014    70
# 1015    92
# 1016    40
# 1017    59
# 1018    63
# 1019    53
# 1020    59
# 1021    55
# 1022    85
# 1023    18
# 1024    83
# 1025    67
# 1026    85
# 1027    46
# 1028    59
# 1029    77
# 1030    71
# 1031    77
# 1032    56
# 1033    79
# 1034    61
# 1035    82
# 1036    76
# 1037    60
# 1038    52
# 1039    88
# 1040    78
# dtype: int64
# 1001    85
# 1002    94
# 1003    63
# 1004    59
# 1005    76
# 1006    64
# 1007    87
# 1008    55
# 1009    51
# 1010    71
# 1011    54
# 1012    94
# 1013    33
# 1014    72
# 1015    75
# 1016    67
# 1017    85
# 1018    15
# 1019    50
# 1020    50
# 1021    19
# 1022    55
# 1023    59
# 1024    65
# 1025    76
# 1026    13
# 1027    57
# 1028    70
# 1029    51
# 1030    94
# 1031    55
# 1032    50
# 1033    71
# 1034    91
# 1035    75
# ...

# %% [markdown]
# ![Screenshot (620).png](attachment:ff2abc6a-92aa-46de-b338-5a7152f6268c.png)

# %%
print(f'Sum of scores in physics:{physics.sum()} \nstudent id {physics.index}')
print(f'Sum of scores in Math: {math.sum()}\nstudent id {math.index}')
# Out:
# Sum of scores in physics:2555
# student id Index([1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012,
#        1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024,
#        1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036,
#        1037, 1038, 1039, 1040],
#       dtype='int32')
# Sum of scores in Math: 2547
# student id Index([1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012,
#        1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024,
#        1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036,
#        1037, 1038, 1039, 1040],
#       dtype='int32')

# %% [markdown]
# ![Screenshot (621).png](attachment:6ef6ae5c-ff98-456b-bc92-9ae34cc18906.png)

# %%
mk=math+physics
mks=mk>=120
print(f'THE STUDENT IDS  OF THE QUALIFYING STUDENTS IS: \n{mk[mks].index}')
# Out:
# THE STUDENT IDS  OF THE QUALIFYING STUDENTS IS:
# Index([1001, 1002, 1003, 1004, 1005, 1006, 1008, 1010, 1011, 1012, 1014, 1015,
#        1017, 1022, 1024, 1025, 1028, 1029, 1030, 1031, 1033, 1034, 1035, 1036,
#        1037, 1038, 1039, 1040],
#       dtype='int32')

# %% [markdown]
# ![Screenshot (622).png](attachment:4c63bc33-d109-4249-83d7-a45f788d3697.png)

# %%
df=pd.DataFrame(mk[mks],columns=['round1qualifiers'])
df
# Out:
#       round1qualifiers
# 1001               120
# 1002               180
# 1003               126
# 1004               149
# 1005               126
# 1006               127
# 1008               127
# 1010               125
# 1011               126
# 1012               177
# 1014               142
# 1015               167
# 1017               144
# 1022               140
# 1024               148
# 1025               143
# 1028               129
# 1029               128
# 1030               165
# 1031               132
# 1033               150
# 1034               152
# 1035               157
# 1036               127
# 1037               150
# 1038               122
# 1039               175
# 1040               134

# %% [markdown]
# ![Screenshot (623).png](attachment:fd32b7b2-c1e8-4fce-a07c-81c32d56474b.png)

# %%
math_ser=pd.Series(maths_marks,index=student_id)
physics_ser=pd.Series(physics_marks,index=student_id)

# %%
p=math_ser+physics_ser

# %%
x=physics_ser[(physics_ser>=50)&(math_ser>=50)&(p==120)]
x
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # since nothing meets the three  condition

# %% [markdown]
# # we chose to put the sum score more than 100 and less than or equal to 120

# %%
x=physics_ser[(physics_ser>=50)&(math_ser>=50)&(p>100)&(p<=120)]
print(f'Student IDS:\n{x.index}')
# Out:
# Student IDS:
# Index([1019, 1020, 1032], dtype='int32')

# %%
df2=pd.DataFrame(x.index,columns=['round2qualifiers'])
df2
# Out:
#    round2qualifiers
# 0              1019
# 1              1020
# 2              1032

# %% [markdown]
# ![Screenshot (624).png](attachment:01a5b449-3f26-48a9-828b-d7c6ab528cbf.png)

# %%
print(f' THE COUNT OF NUMBER OF STUDENTS WHO QUALIFY FOR  ROUND 2  ARE:  {df2.size} STUDENTS  ')
# Out:
#  THE COUNT OF NUMBER OF STUDENTS WHO QUALIFY FOR  ROUND 2  ARE:  3 STUDENTS
