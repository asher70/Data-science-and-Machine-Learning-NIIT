# %% [markdown]
# # ![Screenshot 2025-03-28 094446.png](attachment:952ee88a-f924-4cf1-bd8f-3a0ed1e1c0b5.png)

# %%
from itertools import combinations,combinations_with_replacement,product,permutations

# %% [markdown]
# # 1a)

# %%
len(list(combinations(range(6),r=3)))*len(list(combinations(range(4),r=2)))
# Out:
# 120

# %% [markdown]
# # 1b)

# %%
len(list(combinations(range(6),r=5)))
# Out:
# 6

# %% [markdown]
# # 1c)

# %%
len(list(combinations(range(4),r=3)))*len(list(combinations(range(6),r=2)))+len(list(combinations(range(4),r=4)))*len(list(combinations(range(6),r=1)))
# Out:
# 66

# %% [markdown]
# # 2) option  is the answer

# %% [markdown]
# #

# %% [markdown]
# # ![Screenshot 2025-03-28 094459.png](attachment:5bc7f878-87cc-4229-a8a0-5b78f540f59b.png)

# %%
len(list(combinations(range(52),r=5)))
# Out:
# 2598960

# %% [markdown]
# # 3) option  is the answer

# %% [markdown]
# # ![Screenshot 2025-03-28 094505.png](attachment:faf3c74d-16a3-4042-98b7-30533c4eeb36.png)

# %%
len(list(permutations(range(8),r=3)))
# Out:
# 336

# %% [markdown]
# # option  2 is correct

# %% [markdown]
# # ![Screenshot 2025-03-28 094511.png](attachment:e187c129-ec3e-401b-97a9-0d183baa6670.png)

# %%
def fact(x):
    if x==0 or x==1:
        return 1
    else:
        return x*fact(x-1)

# %%
a=fact(15)# fact of 15

# %%
a
# Out:
# 1307674368000

# %%
b=fact(14)*fact(2)#assuming 13 th +1 as 1 so fact 14 and mult it by 2 students factorial

# %%
b
# Out:
# 174356582400

# %%
a-b
# Out:
# 1133317785600

# %% [markdown]
# # 4 is the correct answer

# %% [markdown]
# # ![Screenshot 2025-03-28 094518.png](attachment:ad822dae-7e4e-47f8-ba9a-84f6bd378df5.png)

# %% [markdown]
# # (1,3)(3,1)(2,6)(6,2)= 4

# %% [markdown]
# # total side of a die 6 *total side of a die 6 =36

# %% [markdown]
# # 4/36 or 1/9

# %% [markdown]
# # 3 rd option

# %% [markdown]
# # ![Screenshot 2025-03-28 094524.png](attachment:0d20c81e-d81d-417b-85fe-b991639b44ca.png)

# %%
pt=len(list(combinations(range(7),r=3)))*len(list(combinations(range(4),r=2)))

# %%
pt*fact(5)# pt words can be arranged in 5! ways so mult with it
# Out:
# 25200

# %%
print(f'thera are about {pt*fact(5)} wordes that can be formed with 3 consonatnts and 2 wovels.')
# Out:
# thera are about 25200 wordes that can be formed with 3 consonatnts and 2 wovels.

# %% [markdown]
# # ![Screenshot 2025-03-28 094530.png](attachment:422948c9-236f-4484-afbc-22932857f2d9.png)

# %% [raw]
# # no of bulbs =25
# % of defective bulbs=25%
# % of non ddefective bulbs =75%
# the first bulb was non defective so 25*0.75=18.75
# since bulb is not an fraction we convert to nearest whole number= 19
# so 19/25 was the first prob sinvce it was non-defective.
# so  since one is removed the probality is 18/24 or 3/4  or 75%

# %% [markdown]
# # 3 rd option 18/24

# %% [markdown]
# # ![Screenshot 2025-03-28 094537.png](attachment:07981ea3-93c9-4342-9bef-e4fd2bc72668.png)

# %% [raw]
# P(F)=46% or 0.46 # probablity of female
# P(P/F)=25% OR 0.25 # probablity of part time/ female
# P(P)=17.4 OR 0.174# probablity of part time workers
# P(F/P)=?
# P(F/P)=P(F AND P)/P(P)
# P(F AND P)=P(P/F)*P(F)=0.25*0.46=0.115
# P(F/P)=0.115/0.174=0.6609 OR 66.09%

# %% [markdown]
# # ![Screenshot 2025-03-28 094543.png](attachment:df734b8c-e293-49c3-af6a-058741d13fa6.png)

# %% [markdown]
# # ![Screenshot 2025-03-28 094548.png](attachment:bec09028-29e8-4893-b8af-3845fb4cd17b.png)

# %% [raw]
# P(R)=0.70
# P(S)=0.67
# P(R AND S)=0.56
# P(S/R)=P(R AND S)/P(R)=0.56/0.70=0.8
# 80% THE WORKER BELIEVES MORE STORAGE SPACE WILL INCREASE PRODUCTIVITY
