# %% [markdown]
# # COURSE 3 SPRINT 2 PRACTISCE(ASSIGNMENT)

# %% [markdown]
# ![Screenshot (460).png](attachment:64760412-1daf-4938-b8a5-cfc77727ddcd.png)
# Task 1: Decision-making Based on User Input
# Write interactive decision-driven programs in Python using Jupyter Notebook, based on the following tasks.
# Accept a character from the user. If the user enters: 'A', then display "Python"
# 'B', then display "MySQL" 'C', then display "Excel"
# If the user enters any other character, then display "Holiday".

# %%
CHARACTER=input("ENTER THE CHARACTER")
if CHARACTER=='A':
    print("Python")
elif CHARACTER=='B':
    print("MySQL")
elif CHARACTER=='C':
    print("Excel")
else :
    print("Holiday")
# Out:
# ENTER THE CHARACTER C
# Excel

# %% [markdown]
# ![Screenshot (461).png](attachment:9e5a6854-ed30-47b1-bd31-da716bcb3429.png)
# Task 2: Comparing Two Numbers
# Accept two numbers from the user and display the higher
# of the two numbers.

# %%
num_1=int(input("ENTER THE FIRST NUMBER"))
num_2=int(input("ENTER THE SECOND NUMBER"))
if num_1>num_2:
    print(f" {num_1} is greater than {num_2} ")
elif num_2>num_1:
    print(f"{num_2}  is greater than {num_1}" )
else:
    print(f" both number {num_1} and {num_2} are equal")
# Out:
# ENTER THE FIRST NUMBER 4
# ENTER THE SECOND NUMBER 5
# 5  is greater than 4

# %% [markdown]
# ![Screenshot (462).png](attachment:f5c704eb-38f0-4678-85ab-53ca297b6294.png)
# Task 3: Calculating Gross Salary
# • If the monthly basic salary is less than $4,000, the user will get 10% HRA and 5% TA on basic salary. If the monthly basic salary is between $4,001 and $10,000, the user will get 10% HRA and 10% TA on basic salary.
# If the monthly basic salary is above $10,000, the
# user will get 15% HRA and 15% TA on basic salary.
# Create a program that accepts basic salary as input and displays the annual gross salary.
# Hint: Gross salary = [(Basic salary) + (HRA on basic salary) + (TA on basic salary)]*12

# %%
#if basic_salary<4000
#hra*0.1 and 0.05*TA
#IF basic_salary>=4001 and basic_salary<= 10000 
#hra*0.1 and 0.1*TA
#IF basic_salary>10000
#hra*0.15 and 0.15*TA

# %%
basic_salary=int(input("Enter the Base salary"))
Gross_salary=0
if basic_salary<4000:
    Gross_salary=(basic_salary +(basic_salary*0.1) + (0.05*basic_salary))*12
    print( f"the total annual salary is: {Gross_salary}" )
elif basic_salary>=4001 and basic_salary<= 10000 :
    Gross_salary=(basic_salary +(basic_salary*0.1) + (0.1*basic_salary))*12
    print( f"the total annual salary is: {Gross_salary}" )
elif basic_salary>10000:
    Gross_salary=(basic_salary +(basic_salary*0.15) + (0.15*basic_salary))*12
    print( f"the total annual salary is: {Gross_salary}" )
# Out:
# Enter the Base salary 11000
# the total annual salary is: 171600.0

# %% [markdown]
# ![Screenshot (463).png](attachment:6d08db5c-2431-484d-b3cf-deef2b561c8d.png)
# Task 4: Searching a Word in a Paragraph
# var = "Python is an interpreted, high-level, general- purpose programming language. Its design philosophy emphasizes code readability, with its use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects."
# Accept a word from the user and check if the word exists in the variable var. Print YES if the word exists, else print NO.

# %%
var = "Python is an interpreted, high-level, general- purpose programming language. Its design philosophy emphasizes code readability, with its use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects."
a=input("Enter the Word")
if a in var:
    print("YES")
else:
    print("NO")
# Out:
# Enter the Word dfgdfgdf
# NO

# %% [markdown]
# ![Screenshot (464).png](attachment:b610e9dd-799a-4692-be40-065e660ff38a.png)
# Task 5: Checking if a Character is Uppercase or Lowercase
# Accept an alphabet from the user. Display if the alphabet entered is uppercase or lowercase.
# For example:
# If the input is A, then the output will be: UPPERCASE
# If the input is a, then the output will be: lowercase

# %%
alphabet=input("Enter the Words or character:")
if alphabet in alphabet.upper():
    print("UPPERCASE")
elif alphabet in alphabet.lower():
    print("lowercase")
else:
    print("NEITHER UPPER nor lowercase")
# Out:
# Enter the Words or character: a
# lowercase

# %% [markdown]
# ![Screenshot (465).png](attachment:efa33265-1a18-429e-a65c-9efaf788d417.png)
# Task 6: Checking if an Alphabet is a Vowel or a Consonant
# Accept an alphabet from the user. Display whether the alphabet entered is a vowel or a consonant.
# For example:
# If the input is a, then the output will be: vowel
# If the input is b, then the output will be: consonant

# %%
vowel=['a','e','i','o','u']
consonant=['b', 'c', 'd', 'f', 'g', 'h', 'j','k','l','m','n','p','q','r','s','t','v', 'w','x', 'y' ,'z']
alphabet=input("Enter the Words or character:")
if  alphabet in vowel:
    print("vowel")
elif alphabet in consonant:
    print("consonant")
else:
    print("neither a vowel or a consonant")
# Out:
# Enter the Words or character: 7
# neither a vowel or a consonant
