# %%
from abc import ABC,abstractmethod
class RiddlePuzzle:
    class playgames(ABC):
        @abstractmethod
        def playgame(self):
            pass
    class brain_teaser(playgames):
        def playgame(self):
            a=int(input("Enter the question number(1-5):"))
            if a==1:
                p=input("A farmer has 17 sheep, and all but 9 run away. How many sheep does the farmer have left?") 
                if p== "9":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","9")
            elif a==2:
                q=input("What has to be broken before you can use it?")
                if q== "egg":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","egg")
            elif a==3:
                q=input("The more of me you take, the more you leave behind. What am I?")
                if q== "Footsteps":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","Footsteps")
            elif a==4:
                q=input("I am an odd number. Take away one letter, and I become even. What am I??")
                if q== "Seven":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","Seven")
            elif a==5:
                q=input("Forward, I am heavy. Backward, I am not. What am I?")
                if q== "ton":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","ton")
            else:
                print("Not a  number from (1-5)")
    class riddle_logic(playgames):
        def playgame(self):
            a=int(input("Enter the question number(1-5):"))
            if a==1:
                p=input("What has many keys but can’t open a single lock?") 
                if p== "piano":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","piano")
            elif a==2:
                q=input("If two’s company, and three’s a crowd, what are four and five?")
                if q== "Nine":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","Nine")
            elif a==3:
                q=input("What has a head, a tail, is brown, and has no legs?")
                if q== "penny":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","penny")
            elif a==4:
                q=input("What has an eye but cannot see?")
                if q== "needle":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","needle")
            elif a==5:
                q=input("What can travel around the world while staying in the same spot?")
                if q== "stamp":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","stamp")
            else:
                print("Not a  number from (1-5)")
    class text_basedgame(playgames):
        def playgame(self):
            a=int(input("Enter the question number(1-5):"))
            if a==1:
                p=input("What has to be broken before you can use it?") 
                if p== "egg":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","egg")
            elif a==2:
                q=input("What has many keys but can't open a single lock?")
                if q== "piano":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","piano")
            elif a==3:
                q=input("The more you share me, the less you have. What am I?")
                if q== "secret":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","secret")
            elif a==4:
                q=input("What has a head, a tail, is brown, and has no legs?")
                if q== "penny":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","penny")
            elif a==5:
                q=input("I’m tall when I’m young, and I’m short when I’m old. What am I?")
                if q== "candle":
                    print("correct")
                    return True
                else:
                    print("incorrect","the correct answer is","candle")
            else:
                print("Not a  number from (1-5)")
    @staticmethod
    def play_game():
        c=0
        p=0
        while True:
            g=RiddlePuzzle().brain_teaser()
            if g.playgame() is True:
                c+=1
            else:
                p+=1
            t=RiddlePuzzle().riddle_logic()
            if t.playgame() is True:
                c+=1
            else:
                p+=1
            j=RiddlePuzzle().text_basedgame()
            if j.playgame() is True:
                c+=1
            else:
                p+=1
            user=input("ENTER THE WORD( type (stop) to end):")
            if user=="stop":
                print(f'You have got {c/(c+p)*100}%') 
            break;

# %%
import random
class ArithmeticPuzzle:
    @staticmethod
    def play_game():
        c=0
        lm=0  
        while True:
            mp=random.randint(1,20)
            l=['+', '-', 'T', '*']
            res=random.choices(l,k=mp)
            #print(res)
            try:
                if 'T'  in res and  res.count('T')>1:
                    q=int(input("What number should replace the question mark? 8 + 4 × 2 = ? "))
                    if q== 16:
                        c+=1
                        print("correct")
                
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","16")
                
                elif '-' in res and res.count('-')>1:
                    p=int(input("Find the next number in the sequence:2, 6, 12, 20, 30,?")) 
                    if p== 42:
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","42")
                elif '+' in  res and res.count('+')>1:
                    q=input("I am an odd number. Take away one letter, and I become even. What am I??")
                    if q== "Seven":
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","Seven")
                elif '*'  in res and res.count('-')>1:
                    q=input("Which operator (×, +, −, ÷) should replace the question mark to make the equation correct?? 12 ? 4 = 48")
                    if q== "×":
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","×")
                elif '+' in res:
                    q=int(input("If 15 × 4 = 60, what is 60 ÷ 15?"))
                    if q== 4:
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","4")
                elif 'T' in res:
                    q=input("At what time between 3 and 4 o'clock will the hour hand and the minute hand overlap?")
                    if q== "3:16":
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","3:16")
                elif '-' in res:
                    q=input("(2 ♥ 3) ♦ 4 = 14")
                    if q== "♥ = ×, ♦ = +":
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","♥ = ×, ♦ = +")
                elif '*' in res:
                    q=int(input("What is the missing number in the series?1, 3, 6, 10, 15, ?"))
                    if q== 21:
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","21")
                
                else:
                    q=int(input("🍎 + 🍎 = 10,🍎 + 🍌 = 14,🍌 + 🍒 = 12,What is the value of 🍎 + 🍌 + 🍒?"))
                    if q== 17:
                        c+=1
                        print("correct")
                    else:
                        lm+=1
                        print("incorrect","the correct answer is","17")


                
                user=input(" to play again type ( 13) to stop(stop)")
                if user=="stop":
                    print(f" the total score is:{c/(c+lm)*100} %")
                    break;
                print("...............Next Round Begins...........")
            except Exception as e:
                print("Error",e)

# %%
class GeneralKnowledge:
    @staticmethod
    def ask_category():
        try:
            print(f' 1)- Science'),
            print(f' 2)-Mathematics')
            print(f' 3)-Geography')
            print(f' 4)-others')
            p=int(input("Enter the categories"))
            return p
        except KeyboardInterrupt as ki:
            print(f"error Input interpreted by the user")
        except EOFError:
            print(f"no input provided by user")  
        except Exception as e :
            print("erro",e)
    @staticmethod      
    def ask_question(question,t):#science,mp
        p=t[question]
        for x,y in p.items():
            print(x)
            correct_answer=y.lower()
        try:
            
            user_answer=input("Enter the answer")
            user_answer=user_answer.lower()
            return user_answer,correct_answer
        except KeyboardInterrupt as ki:
            print(f"error Input interpreted by the user")
        except EOFError:
            print(f"no input provided by user")  
        except Exception as e :
            print("error",e)
    @staticmethod       
    def  check_answer(user_answer, correct_answer):
        if user_answer==correct_answer:
            print("correct")
            return True
        else:
            print("incorrect","the correct answer is: ",correct_answer)
            return False
    @staticmethod 
    def display_score(questions, score):
        percentage_score=(score/(questions))*100
        print("................summary of performance................")
        print(f"  correct answer :{score}")
        print(f"  total_questions :{questions}")
        print(f"  percentage_score :{percentage_score}")
    @staticmethod 
    def exec_questions(at,score,questions):
        if at:
            score+=1
        questions+=1
        return score,questions
    @staticmethod 
    def play_game():
        score=0
        questions=0 
        user=""
        Science=[]
        Mathematics=[]
        Geography=[]
        others=[]
        a='Carbon dioxide'.lower()
        Science.append({'Which gas do plants absorb during photosynthesis? ':a})
        b='World Wide Web'.lower() 
        Science.append({' What is the full name of the WWW? ':b})
        c= '206'
        Science.append({' How many bones are there in the adult human body? ':c})
        Science
        a='2'
        Mathematics.append({'What is the only even prime number?  ':a})  
        b='15'
        Mathematics.append({' What is the sum of the first 5 natural numbers?  ':b})
        c= 'Pi'.lower()
        Mathematics.append({'What is the name of the mathematical symbol π? ':c})
        Mathematics
        a='Mount Everest'.lower()
        Geography.append({'What is the tallest mountain on Earth?  ':a})
        b='Paris'.lower()
        Geography.append({' What is the capital of France?  ':b})
        c= 'Mars'
        Geography.append({'Which planet is known as the "Red Planet"?':c})
        Geography
        a='Argentina'.lower()
        others.append({'Which country won the most recent FIFA World Cup (as of 2022)?  ':a})
        b='Thomas Edison'.lower()
        others.append({' Who invented the light bulb? ':b})
        c= '1950'
        others.append({'In what year did India declare itself a Democratic and Republic state with the adoption of the Constitution? ':c})
        others
        while True:#user=input("enter stop to stop") 
            try:
                c=GeneralKnowledge().ask_category()
                question=int(input("Enter the question number from 0 to 2"))
                if c==1:
                    p,q=GeneralKnowledge().ask_question(question,Science)
                elif c==2:
                    p,q=GeneralKnowledge().ask_question(question,Mathematics)
                elif c==3:
                    p,q=GeneralKnowledge().ask_question(question,Geography)
                elif c==4:
                    p,q=GeneralKnowledge().ask_question(question,others)
        
                at=GeneralKnowledge().check_answer(p,q)
                score,questions= GeneralKnowledge().exec_questions(at,score,questions)  
                user=input("enter stop to end the game")
                if user=="stop":
                    GeneralKnowledge().display_score(questions, score)
                    break;
            except ValueError as v:
                print(v)
            except KeyboardInterrupt as ki:
                print(f"error Input interpreted by the user")
            except EOFError:
                print(f"no input provided by user")  
            except Exception as e :
                print("error",e)

# %%
import random
class RockPaperScissorcomputer:
    @staticmethod
    def play_game():
        Player2=[input("Enter the choice(Rock,Paper,Scissors) ")]
        print(Player2)
        Player1=random.randint(1,1)
        l=['Rock', 'Paper', 'Scissors']
        res=random.choices(l,k=Player1)
        print(res)
        if Player2==res:
            print("DRAW")
        elif Player2==['Scissors']:
            if res==['Paper']:
                print("you win")
            else:
                print("computer win")
        elif Player2==['Paper']:
            if res==['Rock']:
                print('you win')
            else:
                print("computer win")
        elif Player2==['Rock']:
            if res==['Scissors']:
                print('you win')
            else:
                print("computer win")
        else:
            print('Enter the choice correctly')

# %%
import random
class RockPaperScissoruser:
    def play_game():
        P1=input("Hello user1! Enter your name:") 
        P2=input("Hello user2! Enter your name:") 
        Player1=input("Hello user1! Enter a choice (rock, paper, scissors): ")
        Player2=input("Hello user2! Enter a choice (rock, paper, scissors):  ")
        Player1=Player1.lower()
        Player2=Player2.lower()
        if Player1  not in ['rock', 'paper', 'scissors']:
            print(f'{Player1} inputed incorrectly') 
        elif Player2 not in ['rock', 'paper', 'scissors']:
            print(f'{Player2} inputed incorrectly')
        elif Player1 and Player2 not in ['rock', 'paper', 'scissors']:
            print(f'{Player1} and {Player2} inputed incorrectly')  
        elif Player2==Player1:
            print("DRAW")
        elif Player2=='scissors':
            if Player1=='paper':
                print(f"scissors cuts paper!{P2} wins")
            else:
                print(f"{P1} wins")
        elif Player2=='paper':
            if Player1=='rock':
                print(f'paper catches rock!{P2} wins ')
            else:
                print(f"{P1} wins")
        elif Player2=='rock':
            if Player1=='scissors':
                print(f'rock beats scissors!{P2} wins')
            else:
                print(f"{P1} wins ")
        else:
            print('Enter the choice correctly')

# %% [markdown]
# ![Screenshot (584).png](attachment:64fd0dbe-85c5-480b-889e-3c476ddd0730.png)
# Task 1
# Write Python code to develop a word guessing game where
# employees attempt to guess a secret word from a provided list
# by making a series of guesses. Clues, such as optional information
# about the number of letters or characters in the word, can be given
# to assist in the guessing process.

# %%
import random
class word_guessing_game:
    @staticmethod
    def emp_check(employee,p):
        employee=employee.lower()
        if p==employee:
            print("correct")
        else:
            print("incorrect")
            print(f'...First Hint!... ')
            print(f'it is {len(p)} letter word')
            employee=input("Enter the word again")
            employee=employee.lower()
            if p==employee:
                print("correct")
            else:
                print("incorrect")  
                print(f'... Last Hint!... ')
                print(f'it"s  endng three  letters  when reversed are {p[-1:-4:-1]} ')
                employee=input("Enter the word again")
                employee=employee.lower()
                if p==employee:
                    print("correct")
                else:
                    print(f"incorrect,the answer is {p}") 
    @staticmethod
    def play_game():
        #e=(input("Enter your name"))
        most_used_items = ["Laptop","Smartphone","Desk","Chair","Notebook","Pen","Headphones","Water Bottle","Backpack"]
        p=random.choice(most_used_items)
        p=p.lower()
        #employee=input("Enter the word ")
        #employee=employee.lower()
        if p=="laptop":
            print(f'A portable device essential for coding, designing, and presentations.')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="smartphone":
            print(f'A pocket-sized tool for communication, scheduling, and quick research.')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="desk":
            print(f'A flat surface to organize your workspace and keep essentials handy.')    
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="Chair":
            print(f'A seat designed for comfort during long working hours.')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="notebook":
            print(f'A classic tool for jotting down ideas and meeting notes.')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="pen":
            print(f'A simple yet necessary  writing instrument. ')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="headphones":
            print(f' Used for focusing on work or attending virtual meetings.')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="water Bottle":
            print(f'Keeps you hydrated throughout the day. ')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)
        elif p=="backpack":
            print(f'Convenient for carrying work essentials and gadgets. ')
            employee=input("Enter the word ")
            word_guessing_game.emp_check(employee,p)

# %%
word_guessing_game.play_game()
# Out:
# Convenient for carrying work essentials and gadgets.
# Enter the word  bacg
# incorrect
# ...First Hint!...
# it is 8 letter word
# Enter the word again backpasda
# incorrect
# ... Last Hint!...
# it"s  endng three  letters  when reversed are kca
# Enter the word again asf
# incorrect,the answer is backpack

# %% [markdown]
# ![Screenshot (585).png](attachment:9f2353e5-1f72-46ee-a9fa-8877a935c9e5.png)
# Task 2
# Define a method named menu() that prints the following options
# of the application:
# 1. Play Riddle Puzzle.
# 2. Play Arithmetic Puzzle.
# 3. Play General Knowledge quiz game.
# 4. Play Rock-Paper-Scissor game with the computer.
# 5. Play Rock-Paper-Scissor game with a user.
# 6. Play Word-Guessing game with the
# computer.
# Enter any option by typing a number between 1 and 6.

# %% [markdown]
# ![Screenshot (586).png](attachment:2dbb12fd-a694-465b-9171-79c5a88406e6.png)
# Task 2 (cont'd)
# Finally, write the main() method and observe the program's behavior as follows:
# 1. The program will start by printing the application menu. 2. The program will prompt the user to enter an option by choosing a number between 1 and 6.
# 3. If the user enters the option value as 1, then
# execute the program to play the riddle puzzle.

# %% [markdown]
# ![Screenshot (587).png](attachment:a6958de7-d64e-4c72-8f59-54e63ce42283.png)
# Task 2 (cont'd)
# 4. If the user enters the option value as 2, then execute the program to play the arithmetic puzzle.
# 5. If the user enters the option value as 3, then execute
# the program to play the General Knowledge quiz game. 6. If the user enters the option value as 4, then execute the program to play the rock-paper-scissors game with
# the computer.
# 7. If the user enters the option value as 5,
# then execute the program to play the rock-paper-scissors game between
# users.

# %% [markdown]
# ![Screenshot (588).png](attachment:dae47435-dbda-4e46-a2c3-c657ea747387.png)
# Task 2 (cont'd)
# 8. If the user enters the option value as 6, then execute the program to play word guessing game.
# 9. If the user enters any value outside the range of 1 to 6, then the program will display 'You have entered the wrong
# option.'
# 10. The program will prompt the user to enter their
# choice (Y/y for Yes or N/n for No) to either
# repeat the menu to play another game
# or quit the main program.

# %%
def menu():
    try:
        while True:
            print("Welcome to the general knowledge game")
            print("1. Play Riddle Puzzle.")
            print("2. Play Arithmetic Puzzle.")
            print("3. Play General Knowledge quiz game.")
            print("4. Play Rock-Paper-Scissor game with the computer.")
            print("5. Play Rock-Paper-Scissor game with a user.")
            print("6. Play Word-Guessing game with the computer.")
            user=int(input("Enter any option by typing a number between 1 and 6:"))
            if user==1:
                RiddlePuzzle.play_game()
            elif user==2:
                ArithmeticPuzzle.play_game()
            elif user==3:
                GeneralKnowledge.play_game()
            elif user==4:
                RockPaperScissorcomputer.play_game()
            elif user==5:
                RockPaperScissoruser.play_game()
            elif user==6:
                word_guessing_game.play_game()
            else:
                print('You have entered the wrong option.')
                break;
            choice=input("DO YOU WANT TO PLAY AGAIN(Y) OR QUIT(N)")
            choice=choice.lower()
            if choice=="y":
                print("...........NEW GAME BEGINS............")
            elif choice=="n":
                print("Thank you for playing")
                break;
            else:
                print("Invalid") 
                break;
        
    except Exception as e:
        print(f"Error! {e}")
if __name__=="__main__":
    menu()
# Out:
# Welcome to the general knowledge game
# 1. Play Riddle Puzzle.
# 2. Play Arithmetic Puzzle.
# 3. Play General Knowledge quiz game.
# 4. Play Rock-Paper-Scissor game with the computer.
# 5. Play Rock-Paper-Scissor game with a user.
# 6. Play Word-Guessing game with the computer.
# Enter any option by typing a number between 1 and 6: 1
# Enter the question number(1-5): 1
# A farmer has 17 sheep, and all but 9 run away. How many sheep does the farmer have left? 9
# correct
# Enter the question number(1-5): 3
# What has a head, a tail, is brown, and has no legs?
# incorrect the correct answer is penny
# Enter the question number(1-5): 5
# I’m tall when I’m young, and I’m short when I’m old. What am I? candle
# correct
# ENTER THE WORD( type (stop) to end): stop
# You have got 66.66666666666666%
# DO YOU WANT TO PLAY AGAIN(Y) OR QUIT(N) y
# ...........NEW GAME BEGINS............
# Welcome to the general knowledge game
# 1. Play Riddle Puzzle.
# 2. Play Arithmetic Puzzle.
# ...

# %% [markdown]
# ![Screenshot (589).png](attachment:b1eb412f-5b2d-4242-b660-1dec7e20f704.png)
# Task 2 (cont'd)
# 8. If the user enters the option value as 6, then execute the program to play word guessing game.
# 9. If the user enters any value outside the range of 1 to 6, then the program will display 'You have entered the wrong
# option.'
# 10. The program will prompt the user to enter their
# choice (Y/y for Yes or N/n for No) to either
# repeat the menu to play another game
# or quit the main program.

# %%
class GameMenu:
    from abc import ABC,abstractmethod
    class RiddlePuzzle:
        class playgames(ABC):
            @abstractmethod
            def playgame(self):
                pass
        class brain_teaser(playgames):
            def playgame(self):
                a=int(input("Enter the question number(1-5):"))
                if a==1:
                    p=input("A farmer has 17 sheep, and all but 9 run away. How many sheep does the farmer have left?") 
                    if p== "9":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","9")
                elif a==2:
                    q=input("What has to be broken before you can use it?")
                    if q== "egg":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","egg")
                elif a==3:
                    q=input("The more of me you take, the more you leave behind. What am I?")
                    if q== "Footsteps":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","Footsteps")
                elif a==4:
                    q=input("I am an odd number. Take away one letter, and I become even. What am I??")
                    if q== "Seven":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","Seven")
                elif a==5:
                    q=input("Forward, I am heavy. Backward, I am not. What am I?")
                    if q== "ton":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","ton")
                else:
                    print("Not a  number from (1-5)")
        class riddle_logic(playgames):
            def playgame(self):
                a=int(input("Enter the question number(1-5):"))
                if a==1:
                    p=input("What has many keys but can’t open a single lock?") 
                    if p== "piano":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","piano")
                elif a==2:
                    q=input("If two’s company, and three’s a crowd, what are four and five?")
                    if q== "Nine":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","Nine")
                elif a==3:
                    q=input("What has a head, a tail, is brown, and has no legs?")
                    if q== "penny":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","penny")
                elif a==4:
                    q=input("What has an eye but cannot see?")
                    if q== "needle":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","needle")
                elif a==5:
                    q=input("What can travel around the world while staying in the same spot?")
                    if q== "stamp":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","stamp")
                else:
                        print("Not a  number from (1-5)")
        class text_basedgame(playgames):
            def playgame(self):
                a=int(input("Enter the question number(1-5):"))
                if a==1:
                    p=input("What has to be broken before you can use it?") 
                    if p== "egg":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","egg")
                elif a==2:
                    q=input("What has many keys but can't open a single lock?")
                    if q== "piano":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","piano")
                elif a==3:
                    q=input("The more you share me, the less you have. What am I?")
                    if q== "secret":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","secret")
                elif a==4:
                    q=input("What has a head, a tail, is brown, and has no legs?")
                    if q== "penny":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","penny")
                elif a==5:
                    q=input("I’m tall when I’m young, and I’m short when I’m old. What am I?")
                    if q== "candle":
                        print("correct")
                        return True
                    else:
                        print("incorrect","the correct answer is","candle")
                else:
                    print("Not a  number from (1-5)")
        @staticmethod
        def play_game():
            c=0
            p=0
            while True:
                g=RiddlePuzzle().brain_teaser()
                if g.playgame() is True:
                    c+=1
                else:
                    p+=1
                t=RiddlePuzzle().riddle_logic()
                if t.playgame() is True:
                    c+=1
                else:
                    p+=1
                j=RiddlePuzzle().text_basedgame()
                if j.playgame() is True:
                    c+=1
                else:
                    p+=1
                user=input("ENTER THE WORD( type (stop) to end):")
                if user=="stop":
                    print(f'You have got {c/(c+p)*100}%') 
                    break;
    import random
    class ArithmeticPuzzle:
        @staticmethod
        def play_game():
            c=0
            lm=0  
            while True:
                mp=random.randint(1,20)
                l=['+', '-', 'T', '*']
                res=random.choices(l,k=mp)
                #print(res)
                try:
                    if 'T'  in res and  res.count('T')>1:
                        q=int(input("What number should replace the question mark? 8 + 4 × 2 = ? "))
                        if q== 16:
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","16")
                
                    elif '-' in res and res.count('-')>1:
                        p=int(input("Find the next number in the sequence:2, 6, 12, 20, 30,?")) 
                        if p== 42:
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","42")
                    elif '+' in  res and res.count('+')>1:
                        q=input("I am an odd number. Take away one letter, and I become even. What am I??")
                        if q== "Seven":
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","Seven")
                    elif '*'  in res and res.count('-')>1:
                        q=input("Which operator (×, +, −, ÷) should replace the question mark to make the equation correct?? 12 ? 4 = 48")
                        if q== "×":
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","×")
                    elif '+' in res:
                        q=int(input("If 15 × 4 = 60, what is 60 ÷ 15?"))
                        if q== 4:
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","4")
                    elif 'T' in res:
                        q=input("At what time between 3 and 4 o'clock will the hour hand and the minute hand overlap?")
                        if q== "3:16":
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","3:16")
                    elif '-' in res:
                        q=input("(2 ♥ 3) ♦ 4 = 14")
                        if q== "♥ = ×, ♦ = +":
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","♥ = ×, ♦ = +")
                    elif '*' in res:
                        q=int(input("What is the missing number in the series?1, 3, 6, 10, 15, ?"))
                        if q== 21:
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","21")
                
                    else:
                        q=int(input("🍎 + 🍎 = 10,🍎 + 🍌 = 14,🍌 + 🍒 = 12,What is the value of 🍎 + 🍌 + 🍒?"))
                        if q== 17:
                            c+=1
                            print("correct")
                        else:
                            lm+=1
                            print("incorrect","the correct answer is","17")

                  
                
                    user=input(" to play again type ( 13) to stop(stop)")
                    if user=="stop":
                        print(f" the total score is:{c/(c+lm)*100} %")
                        break;
                    print("...............Next Round Begins...........")
                except Exception as e:
                    print("Error",e)
    class GeneralKnowledge:
        @staticmethod
        def ask_category():
            try:
                print(f' 1)- Science'),
                print(f' 2)-Mathematics')
                print(f' 3)-Geography')
                print(f' 4)-others')
                p=int(input("Enter the categories"))
                return p
            except KeyboardInterrupt as ki:
                print(f"error Input interpreted by the user")
            except EOFError:
                print(f"no input provided by user")  
            except Exception as e :
                print("erro",e)
        @staticmethod      
        def ask_question(question,t):#science,mp
            p=t[question]
            for x,y in p.items():
                print(x)
                correct_answer=y.lower()
            try:
                user_answer=input("Enter the answer")
                user_answer=user_answer.lower()
                return user_answer,correct_answer
            except KeyboardInterrupt as ki:
                print(f"error Input interpreted by the user")
            except EOFError:
                print(f"no input provided by user")  
            except Exception as e :
                print("error",e)
        @staticmethod       
        def  check_answer(user_answer, correct_answer):
            if user_answer==correct_answer:
                print("correct")
                return True
            else:
                print("incorrect","the correct answer is: ",correct_answer)
                return False
        @staticmethod 
        def display_score(questions, score):
            percentage_score=(score/(questions))*100
            print("................summary of performance................")
            print(f"  correct answer :{score}")
            print(f"  total_questions :{questions}")
            print(f"  percentage_score :{percentage_score}")
        @staticmethod 
        def exec_questions(at,score,questions):
            if at:
                score+=1
                questions+=1
                return score,questions
        @staticmethod 
        def play_game():
            score=0
            questions=0 
            user=""
            Science=[]
            Mathematics=[]
            Geography=[]
            others=[]
            a='Carbon dioxide'.lower()
            Science.append({'Which gas do plants absorb during photosynthesis? ':a})
            b='World Wide Web'.lower() 
            Science.append({' What is the full name of the WWW? ':b})
            c= '206'
            Science.append({' How many bones are there in the adult human body? ':c})
            Science
            a='2'
            Mathematics.append({'What is the only even prime number?  ':a})  
            b='15'
            Mathematics.append({' What is the sum of the first 5 natural numbers?  ':b})
            c= 'Pi'.lower()
            Mathematics.append({'What is the name of the mathematical symbol π? ':c})
            Mathematics
            a='Mount Everest'.lower()
            Geography.append({'What is the tallest mountain on Earth?  ':a})
            b='Paris'.lower()
            Geography.append({' What is the capital of France?  ':b})
            c= 'Mars'
            Geography.append({'Which planet is known as the "Red Planet"?':c})
            Geography
            a='Argentina'.lower()
            others.append({'Which country won the most recent FIFA World Cup (as of 2022)?  ':a})
            b='Thomas Edison'.lower()
            others.append({' Who invented the light bulb? ':b})
            c= '1950'
            others.append({'In what year did India declare itself a Democratic and Republic state with the adoption of the Constitution? ':c})
            others
            while True:#user=input("enter stop to stop") 
                try:
                    c=GeneralKnowledge().ask_category()
                    question=int(input("Enter the question number from 0 to 2"))
                    if c==1:
                        p,q=GeneralKnowledge().ask_question(question,Science)
                    elif c==2:
                        p,q=GeneralKnowledge().ask_question(question,Mathematics)
                    elif c==3:
                        p,q=GeneralKnowledge().ask_question(question,Geography)
                    elif c==4:
                        p,q=GeneralKnowledge().ask_question(question,others)
        
                    at=GeneralKnowledge().check_answer(p,q)
                    score,questions= GeneralKnowledge().exec_questions(at,score,questions)  
                    user=input("enter stop to end the game")
                    if user=="stop":
                        GeneralKnowledge().display_score(questions, score)
                        break;
                except ValueError as v:
                    print(v)
                except KeyboardInterrupt as ki:
                    print(f"error Input interpreted by the user")
                except EOFError:
                    print(f"no input provided by user")  
                except Exception as e :
                    print("error",e)
            
        
    import random
    class RockPaperScissorcomputer:
        @staticmethod
        def play_game():
            Player2=[input("Enter the choice(Rock,Paper,Scissors) ")]
            print(Player2)
            Player1=random.randint(1,1)
            l=['Rock', 'Paper', 'Scissors']
            res=random.choices(l,k=Player1)
            print(res)
            if Player2==res:
                print("DRAW")
            elif Player2==['Scissors']:
                if res==['Paper']:
                    print("you win")
                else:
                    print("computer win")
            elif Player2==['Paper']:
                if res==['Rock']:
                    print('you win')
                else:
                    print("computer win")
            elif Player2==['Rock']:
                if res==['Scissors']:
                    print('you win')
                else:
                    print("computer win")
            else:
                print('Enter the choice correctly')        
        
    import random
    class RockPaperScissoruser:
        def play_game():
            P1=input("Hello user1! Enter your name:") 
            P2=input("Hello user2! Enter your name:") 
            Player1=input("Hello user1! Enter a choice (rock, paper, scissors): ")
            Player2=input("Hello user2! Enter a choice (rock, paper, scissors):  ")
            Player1=Player1.lower()
            Player2=Player2.lower()
            if Player1  not in ['rock', 'paper', 'scissors']:
                print(f'{Player1} inputed incorrectly') 
            elif Player2 not in ['rock', 'paper', 'scissors']:
                print(f'{Player2} inputed incorrectly')
            elif Player1 and Player2 not in ['rock', 'paper', 'scissors']:
                print(f'{Player1} and {Player2} inputed incorrectly')  
            elif Player2==Player1:
                print("DRAW")
            elif Player2=='scissors':
                if Player1=='paper':
                    print(f"scissors cuts paper!{P2} wins")
                else:
                    print(f"{P1} wins")
            elif Player2=='paper':
                if Player1=='rock':
                    print(f'paper catches rock!{P2} wins ')
                else:
                    print(f"{P1} wins")
            elif Player2=='rock':
                if Player1=='scissors':
                    print(f'rock beats scissors!{P2} wins')
                else:
                    print(f"{P1} wins ")
            else:
                print('Enter the choice correctly')    
    import random
    class word_guessing_game:
        @staticmethod
        def emp_check(employee,p):
            employee=employee.lower()
            if p==employee:
                print("correct")
            else:
                print("incorrect")
                print(f'...First Hint!... ')
                print(f'it is {len(p)} letter word')
                employee=input("Enter the word again")
                employee=employee.lower()
                if p==employee:
                    print("correct")
                else:
                    print("incorrect")  
                    print(f'... Last Hint!... ')
                    print(f'it"s  endng three  letters  when reversed are {p[-1:-4:-1]} ')
                    employee=input("Enter the word again")
                    employee=employee.lower()
                    if p==employee:
                        print("correct")
                    else:
                        print(f"incorrect,the answer is {p}") 
        @staticmethod
        def play_game():
            #e=(input("Enter your name"))
             most_used_items = ["Laptop","Smartphone","Desk","Chair","Notebook","Pen","Headphones","Water Bottle","Backpack"]
             p=random.choice(most_used_items)
             p=p.lower()
             #employee=input("Enter the word ")
             #employee=employee.lower()
             if p=="laptop":
                 print(f'A portable device essential for coding, designing, and presentations.')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="smartphone":
                 print(f'A pocket-sized tool for communication, scheduling, and quick research.')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="desk":
                 print(f'A flat surface to organize your workspace and keep essentials handy.')    
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="Chair":
                 print(f'A seat designed for comfort during long working hours.')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="notebook":
                 print(f'A classic tool for jotting down ideas and meeting notes.')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="pen":
                 print(f'A simple yet necessary  writing instrument. ')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="headphones":
                 print(f' Used for focusing on work or attending virtual meetings.')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="water Bottle":
                 print(f'Keeps you hydrated throughout the day. ')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)
             elif p=="backpack":
                 print(f'Convenient for carrying work essentials and gadgets. ')
                 employee=input("Enter the word ")
                 word_guessing_game.emp_check(employee,p)

    @staticmethod
    def menu():
        try:
            while True:
                print("Welcome to the general knowledge game")
                print("1. Play Riddle Puzzle.")
                print("2. Play Arithmetic Puzzle.")
                print("3. Play General Knowledge quiz game.")
                print("4. Play Rock-Paper-Scissor game with the computer.")
                print("5. Play Rock-Paper-Scissor game with a user.")
                print("6. Play Word-Guessing game with the computer.")
                user=int(input("Enter any option by typing a number between 1 and 6:"))
                if user==1:
                    RiddlePuzzle.play_game()
                elif user==2:
                    ArithmeticPuzzle.play_game()
                elif user==3:
                    GeneralKnowledge.play_game()
                elif user==4:
                    RockPaperScissorcomputer.play_game()
                elif user==5:
                    RockPaperScissoruser.play_game()
                elif user==6:
                    word_guessing_game.play_game()
                else:
                    print('You have entered the wrong option.')
                    break;
                choice=input("DO YOU WANT TO PLAY AGAIN(Y) OR QUIT(N)")
                choice=choice.lower()
                if choice=="y":
                    print("...........NEW GAME BEGINS............")
                elif choice=="n":
                    print("Thank you for playing")
                    break;
                else:
                    print("Invalid") 
                    break;
        except Exception as e:
            print(f"Error! {e}")
    if __name__=="__main__":
        menu()
# Out:
# Welcome to the general knowledge game
# 1. Play Riddle Puzzle.
# 2. Play Arithmetic Puzzle.
# 3. Play General Knowledge quiz game.
# 4. Play Rock-Paper-Scissor game with the computer.
# 5. Play Rock-Paper-Scissor game with a user.
# 6. Play Word-Guessing game with the computer.
# Enter any option by typing a number between 1 and 6: 6
# A flat surface to organize your workspace and keep essentials handy.
# Enter the word  note
# incorrect
# ...First Hint!...
# it is 4 letter word
# Enter the word again chair
# incorrect
# ... Last Hint!...
# it"s  endng three  letters  when reversed are kse
# Enter the word again know
# incorrect,the answer is desk
# DO YOU WANT TO PLAY AGAIN(Y) OR QUIT(N) n
# Thank you for playing

# %%
GameMenu.menu()
# Out:
# Welcome to the general knowledge game
# 1. Play Riddle Puzzle.
# 2. Play Arithmetic Puzzle.
# 3. Play General Knowledge quiz game.
# 4. Play Rock-Paper-Scissor game with the computer.
# 5. Play Rock-Paper-Scissor game with a user.
# 6. Play Word-Guessing game with the computer.
# Enter any option by typing a number between 1 and 6: 3
#  1)- Science
#  2)-Mathematics
#  3)-Geography
#  4)-others
# Enter the categories 4
# Enter the question number from 0 to 2 2
# In what year did India declare itself a Democratic and Republic state with the adoption of the Constitution?
# Enter the answer 1950
# correct
# enter stop to end the game stop
# ................summary of performance................
#   correct answer :1
#   total_questions :1
#   percentage_score :100.0
# DO YOU WANT TO PLAY AGAIN(Y) OR QUIT(N) n
# Thank you for playing
